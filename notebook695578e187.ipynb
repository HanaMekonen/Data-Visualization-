# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *

# %%
step_1.check()

# %%
#  Specify the path of the CSV file to read
my_filepath="../input/accelerometer-record/Total Accelerometer data.csv"
# Check for a valid filepath to a CSV file in a dataset
step_2.check()

# %%
#  Read the file into a variable my_data
columns = ['subject','Activity','timestamp', 'x-axis', 'y-axis', 'z-axis']
my_data = pd.read_csv(my_filepath,header = None, names = columns)

# Check that a dataset has been uploaded into my_data
step_3.check()

# %%
# Print the first five rows of the data
my_data.head()

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10, 5))
sns.countplot(x = 'Activity', data = my_data)
plt.title('Number of samples by activity')
plt.show()
